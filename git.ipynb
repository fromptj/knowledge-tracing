# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# !pwd && ls -al
# Out:
# /content/drive/MyDrive/Colab Notebooks/knowledge-tracing
# total 27
# drwx------ 4 root root  4096 Mar  5 13:07 data
# -rw------- 1 root root 13419 Mar  5 15:15 dkt.ipynb
# drwx------ 8 root root  4096 Mar  5 15:21 .git
# -rw------- 1 root root  5412 Mar  5 15:21 git.ipynb

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/knowledge-tracing/.git/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/knowledge-tracing
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# /content/drive/MyDrive/Colab Notebooks/knowledge-tracing

# %%
# !git remote add origin https://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@github.com/fromptj/knowledge-tracing.git

# %%
# !git remote remove origin

# %%
# !git pull origin master --allow-unrelated-histories
# Out:
# From https://github.com/fromptj/knowledge-tracing
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !git merge
# Out:
# fatal: You have not concluded your merge (MERGE_HEAD exists).
# Please, commit your changes before you merge.

# %%
# !git add .
# !git commit -m "merge용"
# Out:
# [master 03df738] merge용
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 570 bytes | 285.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/fromptj/knowledge-tracing.git
#    411b733..03df738  master -> master
